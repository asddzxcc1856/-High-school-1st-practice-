# %% [markdown]
# <a href="https://colab.research.google.com/github/asddzxcc1856/-High-school-1st-practice-/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
a = "hello"
a += " world"
print(a)
# Out:
# hello world
